# %%
import awswrangler as wr

DATABASE = "wishbone-glue-db"

# %%
query = "SELECT * FROM listing"
wr.athena.read_sql_query(query, database=DATABASE)
# Out:
#    listing_id  game_id  platform_id  price  discount_percent recording_date  \
# 0           1        2            1      1                99     2025-11-18
#
#    year month day
# 0  2025    11  18
