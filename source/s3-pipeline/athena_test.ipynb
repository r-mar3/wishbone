# %%
import awswrangler as wr

DATABASE = "wishbone-glue-db"

# %%
query = "SELECT * FROM listing"
wr.athena.read_sql_query(query, database=DATABASE)
# Out:
#       listing_id  game_id  platform_id  price  discount_percent  \
# 0           3294     2053            1    846                 0
# 1           3295     2054            1    677                20
# 2           3296     2055            1    242                65
# 3           3297     2056            1    769                 0
# 4           3298     2057            1    769                 0
# ...          ...      ...          ...    ...               ...
# 4005        2044     2045            1    769                 0
# 4006        2045     2046            1    192                75
# 4007        2046     2047            1   1154                 0
# 4008        2047     2048            1    384                 0
# 4009        2048     2049            1    384                 0
#
#      recording_date  year month day
# 0        2025-11-20  2025    11  20
# 1        2025-11-20  2025    11  20
# 2        2025-11-20  2025    11  20
# 3        2025-11-20  2025    11  20
# 4        2025-11-20  2025    11  20
# ...             ...   ...   ...  ..
# 4005     2025-11-19  2025    11  19
# 4006     2025-11-19  2025    11  19
# 4007     2025-11-19  2025    11  19
# 4008     2025-11-19  2025    11  19
# 4009     2025-11-19  2025    11  19
#
# [4010 rows x 9 columns]
